# %% [markdown]
# # 02 Průzkumová Analýza Dat

# %%
#obecné nastavení
barva=["#2E2300","#DB9501","#375E97","#3F681C","#C05805"]

# %% [markdown]
# ## Načtení dat

# %% [markdown]
# Načtěte data ze souboru .csv do data framu s názvem **hrubaData**.

# %%
#umístění souboru
soubor="R:/-DigitalAcademy-/Clustering/trickaData.csv"

# %%
#import knihovny
import pandas as pd

# %%
#načtení dat
hrubaData=pd.read_csv(soubor)

# %% [markdown]
# ## Základní číselné charakteristiky

# %% [markdown]
# Zjistěte základní údaje o data framu **hrubaData**.
#
# * Rozměry.
# * Základní statistické údaje - min, max, ...
# * Cokoliv dalšího vás napadne.
# * Vypiště prvních 7 a posledních 10 řádků data framu.

# %%
#kontrola typu data framu
type(hrubaData)
# Out:
# pandas.core.frame.DataFrame

# %%
#rozměry data framu
hrubaData.shape
# Out:
# (202, 3)

# %%
#základní statistické údaje
hrubaData.describe()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             Cislo       Sirka        Delka
# count  202.000000  201.000000   202.000000
# mean   101.500000   50.919502   683.594554
# std     58.456537   10.507498    48.682815
# min      1.000000   20.000000   559.600000
# 25%     51.250000         NaN   651.100000
# 50%    101.500000         NaN   677.800000
# 75%    151.750000         NaN   705.700000
# max    202.000000   85.360000  1000.000000

# %%
# NaN
print(hrubaData.isnull().sum())
hrubaData[hrubaData["Sirka"].isnull()]
# Out:
# Cislo    0
# Sirka    1
# Delka    0
# dtype: int64
#      Cislo  Sirka  Delka
# 201    202    NaN  760.0

# %%
#prvních 7 řádků data framu
hrubaData.head(7)
# Out:
#    Cislo  Sirka  Delka
# 0      1  45.99  662.5
# 1      2  43.64  661.5
# 2      3  56.83  691.2
# 3      4  53.90  662.7
# 4      5  35.87  703.8
# 5      6  48.66  700.3
# 6      7  59.20  807.9

# %%
#posledních 10 řádků data framu
hrubaData.tail(10)
# Out:
#      Cislo  Sirka   Delka
# 192    193  85.36   594.2
# 193    194  61.77   817.6
# 194    195  34.65   733.6
# 195    196  47.79   677.8
# 196    197  43.31   675.9
# 197    198  62.48   689.6
# 198    199  58.62   693.4
# 199    200  47.78   682.3
# 200    201  20.00  1000.0
# 201    202    NaN   760.0

# %%
#celá data
hrubaData
# Out:
#      Cislo  Sirka   Delka
# 0        1  45.99   662.5
# 1        2  43.64   661.5
# 2        3  56.83   691.2
# 3        4  53.90   662.7
# 4        5  35.87   703.8
# 5        6  48.66   700.3
# 6        7  59.20   807.9
# 7        8  49.72   628.3
# 8        9  60.58   720.6
# 9       10  40.65   672.8
# 10      11  47.96   638.3
# 11      12  53.56   670.9
# 12      13  43.67   687.9
# 13      14  47.11   648.5
# 14      15  29.97   671.1
# 15      16  66.91   730.5
# 16      17  40.27   647.0
# 17      18  49.74   679.1
# 18      19  53.98   709.0
# 19      20  50.25   721.6
# 20      21  40.72   640.9
# 21      22  51.48   707.2
# 22      23  48.20   682.9
# 23      24  61.12   720.5
# 24      25  37.32   667.0
# 25      26  55.67   732.9
# 26      27  37.53   637.5
# 27      28  48.82   650.2
# 28      29  54.59   605.9
# 29      30  44.31   643.2
# ..     ...    ...     ...
# 172    173  45.65   764.4
# 173    174  40.47   658.4
# 174    175  41.29   692.7
# ...

# %% [markdown]
# ## První vykreslení

# %% [markdown]
# Nyní vykreslíme data frame **hrubaData**:
# * Použita je knihovna matplotlib.
# * Zvoleno je bodové vykreslení grafu.
#
# Graf je z větší části hotový, vaším úkolem je něco změnit (použijte rozum, zkoušejte, použijte google, dokumentaci, zkuste si poradit):
# * Změňte barvu bodů na červenou.
# * Zmenšete velikost bodů na třetinu.
# * Změňte barvu hranice na zelenou.
#
# A navíc ještě něco přidejte.
# * Popiště vhodně obě osy.
# * Vložte vhodný nadpis do obrázku.
# * Nastavte osy tak, aby měli obě stejnou velikost měřítka, aby byly ekvivalentní.
#
# Informační zdroje:
#
# * [Google](www.google.cz)
# * [Matplotlib web](http://matplotlib.org/)

# %%
# import knihovny
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
#vytáhnu si obě datové sady - lepší opakovatelnost kódu.
x=hrubaData["Sirka"]
y=hrubaData["Delka"]

#základ obrázku
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])

#bodový obrázek
ax.scatter(
        x=x,
        y=y,
        c=barva[4],
        s=300,
        alpha=0.5,
        edgecolors=barva[0]
)

#pojmenování os
#ax.set_xlabel(x.name)
#ax.set_ylabel(y.name)
#ax.set_title("Úvodní vizualizace dat")

#nastavení os
#plt.axis("equal")

#ax.set_xlim([])
#ax.set_ylim([])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Vyhodnocení

# %% [markdown]
# Napiště v několika bodech, co jste zjistili a jaký navrhujete další postup.
#
# * Pvní bod ...
#
# Pokuste se zodpovědět na následující otázky.
#
# * Dávají data smysl?
# * Jsou data v pořádku?
# * Napadjí vás nějaké úpravy dat, které by bylo dobré provést?

# %% [markdown]
# ## Předzpracování dat

# %% [markdown]
# Na základě výše uvedené prvotní analýzy bylo zjištěno následující.
#
# * Data obsahují outlier - jedná se o jedno pozorování a proto bude vyřazeno.
# * Data mají špatné měřítko, šířka jse v cm, délka je mm. Rozhodnuto o převedení na cm.
# * Přejmenování sluopců s ohledem na jednotky.
# * Data obsahují jednu NaN hodnotu - bude vyřazena.
#
# Vytvořte **nový** data frame **cistaData**, kde budou vyřešeny výše uvedené problémy.
#
# > Pozn.: Outlier a NaN value jsou dva poslední řádky data framu.

# %%
#vytvořím kopii bez posledních dvou pozorování - outlier a řádek obsahující NaN
cistaData=hrubaData[0:200].copy()

#převod z mm na cm
cistaData["Delka"]=cistaData["Delka"]/10

#přejmenování
cistaData.rename(columns={"Sirka":"Sirka [cm]","Delka":"Delka [cm]"},inplace=True)

# %%
#zobrazení
cistaData.head()
# Out:
#    Cislo  Sirka [cm]  Delka [cm]
# 0      1       45.99       66.25
# 1      2       43.64       66.15
# 2      3       56.83       69.12
# 3      4       53.90       66.27
# 4      5       35.87       70.38

# %%
cistaData.tail()
# Out:
#      Cislo  Sirka [cm]  Delka [cm]
# 195    196       47.79       67.78
# 196    197       43.31       67.59
# 197    198       62.48       68.96
# 198    199       58.62       69.34
# 199    200       47.78       68.23

# %%
#kontrola typu data framu
type(cistaData)
# Out:
# pandas.core.frame.DataFrame

# %%
#rozměry data framu
cistaData.shape
# Out:
# (200, 3)

# %%
#základní statistické údaje
cistaData.describe()
# Out:
#             Cislo       Sirka        Delka
# count  202.000000  201.000000   202.000000
# mean   101.500000   50.919502   683.594554
# std     58.456537   10.507498    48.682815
# min      1.000000   20.000000   559.600000
# 25%     51.250000   43.840000   651.100000
# 50%    101.500000   48.850000   677.800000
# 75%    151.750000   57.740000   705.700000
# max    202.000000   85.360000  1000.000000

# %%
# NaN
print(cistaData.isnull().sum())
cistaData[cistaData["Sirka"].isnull()]
# Out:
# Cislo    0
# Sirka    0
# Delka    0
# dtype: int64
# Empty DataFrame
# Columns: [Cislo, Sirka, Delka]
# Index: []

# %% [markdown]
# ## Druhé vykreslení dat

# %% [markdown]
# Analogicky předchozí situaci vykreslete data.

# %%
#vykreslení

#celé níže smazat ----------------------

#vytáhnu si obě datové sady - lepší opakovatelnost kódu.
x=cistaData["Sirka [cm]"]
y=cistaData["Delka [cm]"]

#základ obrázku
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])

#bodový obrázek
ax.scatter(
        x=x,
        y=y,
        c=barva[3],
        s=30,
        alpha=0.5,
        edgecolors=barva[0]
)

#pojmenování os
ax.set_xlabel(x.name)
ax.set_ylabel(y.name)
ax.set_title("Vizualizace čistých dat")

#nastavení os
plt.axis("equal")
#ax.set_xlim([])
#ax.set_ylim([])
# Out:
# <img src="data:image/png;base64,...">
# (20.0, 90.0, 50.0, 85.0)

# %% [markdown]
# # Poznámky

# %% [markdown]
# ## Zpět k otázkám
#
# **Otázky** jsou to nejdůležitější. Mějte je pořád na paměti! V tuto chvíli je ideální příležitost si je projít/zopakovat/pozměnit.

# %% [markdown]
# ## Jak si tu syntaxi mám pamatovat?
#
# Nevíš?
# * Zeptej se [googlu](www.google.com)
# * Použij dokumentaci k pythonu pro danou knihovnu.

# %% [markdown]
# ## Projektové řízení - raw skript vs final skript
#
# **Raw script**
# * Jde o to udělat si základní představu, paretovské pravidlo 20 vs 80 - za minimum času maximum výsledku.
#
# **Final script**
# * Pro nadřízené, vím, co tam má být na základě raw scripts, proto věnuji více péče estetické a formální stránce.

# %% [markdown]
# ## Reproducible research
#
# **Reproducible research**
# * Obecným požadavkem je tzv. [reproducible research](https://www.r-bloggers.com/what-is-reproducible-research/), o jehož důležitosti si povíme více dále v bloku.

# %% [markdown]
# ## Proč python?
#
# * Který nástroj umožňuje reproducible research?
# * Co když mají data více než 1 048 576 řádků? Internetové kampaně - řádově miliony zobrazení.

# %% [markdown]
# ## DÚ
#
# * Doplňte část týkající se kapitoly *Průzkumová analáza dat* do finálního reportu.
# * Použij google/dokumentaci knihovny, aby obrázek ve finálním reportu splňoval všechny popsané vlastnosti.
# * Zjistěte si, co je to reproducible research a zamysli se nad tím, proč by to mělo být důležité?
